# %% [markdown]
# # Dataset: Flujo Vehicular por Unidades de Peaje AUSA
#
# by Alina Martinez - [Github](https://github.com/martinezalina/illia-p4)
#
# ## Objetivo
#
# Generar un dataset en **CSV de lectura rápida** del flujo vehicular por Unidades de Peaje AUSA de año 2020 basado en los datasets oficiales, provistos en https://data.buenosaires.gob.ar/dataset/flujo-vehicular-por-unidades-peaje-ausa.
#
# El procesamiento inicial de los XLS provistos, tienen una demora superior a los CSV. Es por ello que se opta por hacer un preprocesamiento y almacenar un CSV, listo para continuar trabajando en el proyecto principal.

# %% [markdown]
# ## Librerías

# %%
# Importamos las Librerías que vamos a utilizar

from IPython.display import display, Markdown
import warnings

#Warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Configuro Notebook

# %%
# Format round off to two decimal places in pandas 
pd.options.display.float_format = '{: .2f}'.format

# %% [markdown]
# ## Lectura de los Dataset

# %%
# Para cambiar la modalidad de carga de los datasets a CDN, descomentar la segunda línea.

cdn_mode = False
#cdn_mode = True

if cdn_mode:
  data_2020_Q1 = pd.read_excel('https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ausa/flujo-vehicular-por-unidades-peaje-ausa/flujo-vehicular-2020%20ene-abr.xlsx')
  data_2020_Q2 = pd.read_excel('https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ausa/flujo-vehicular-por-unidades-peaje-ausa/flujo-vehicular-2020-2.xlsx')
  data_2020_Q3 = pd.read_excel('https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ausa/flujo-vehicular-por-unidades-peaje-ausa/flujo-vehicular-20203.xlsx')
else:
  data_2020_Q1 = pd.read_excel('./datasets/flujo-vehicular-2020-q1.xlsx')
  data_2020_Q2 = pd.read_excel('./datasets/flujo-vehicular-2020-q2.xlsx')
  data_2020_Q3 = pd.read_excel('./datasets/flujo-vehicular-2020-q3.xlsx')

# %%
data_2020_Q1
# Out:
#         Unnamed: 0  periodo                fecha    mes        dia  dia_fecha  \
# 0                0     2020  2020-01-01 00:00:00  enero  Miércoles          1
# 1                1     2020  2020-01-01 00:00:00  enero  Miércoles          1
# 2                2     2020  2020-01-01 00:00:00  enero  Miércoles          1
# 3                3     2020  2020-01-01 00:00:00  enero  Miércoles          1
# 4                4     2020  2020-01-01 00:00:00  enero  Miércoles          1
# ...            ...      ...                  ...    ...        ...        ...
# 821921      821921     2020           2020-04-30  abril     Jueves         30
# 821922      821922     2020           2020-04-30  abril     Jueves         30
# 821923      821923     2020           2020-04-30  abril     Jueves         30
# 821924      821924     2020           2020-04-30  abril     Jueves         30
# 821925      821925     2020           2020-04-30  abril     Jueves         30
#
#         hora_inicio  hora_fin estacion   tipo_vehiculo forma_pago  \
# 0                 0         1  ALBERDI            Auto   Efectivo
# 1                 0         1  ALBERDI            Auto   Efectivo
# 2                 0         1  ALBERDI            Auto  Rec.Deuda
# 3                 0         1  ALBERDI            Auto  Rec.Deuda
# 4                 0         1  ALBERDI            Auto  Rec.Deuda
# ...             ...       ...      ...             ...        ...
# 821921           23         0      PB2  Pesados 6 Ejes        Tag
# 821922           23         0      PB2  Pesados 6 Ejes        Tag
# 821923           23         0      PB4  Pesados 6 Ejes        Tag
# 821924           23         0      PB4  Pesados 6 Ejes  Violación
# 821925           23         0   RETIRO  Pesados 6 Ejes        Tag
#
#                              observacion    sentido  cantidad_pasos
# 0                               Efectivo     Centro              24
# 1                               Efectivo  Provincia              80
# 2                     Paso en Infracción  Provincia               1
# 3       Paso en infracción con Multa LPR     Centro               1
# 4       Paso en infracción con Multa LPR  Provincia               1
# ...                                  ...        ...             ...
# 821921                     Tag - PosPago     Centro               2
# 821922                 Tag - PosPago OCR     Centro               1
# 821923                     Tag - PosPago     Centro              12
# 821924                Violación - Normal     Centro               1
# 821925                     Tag - PosPago  Provincia               2
#
# [821926 rows x 14 columns]

# %%
data_2020_Q2
# Out:
#         Unnamed: 0  periodo                fecha     mes      dia  dia_fecha  \
# 0        821926.00     2020           2020-05-01    mayo  Viernes          1
# 1        821927.00     2020           2020-05-01    mayo  Viernes          1
# 2        821928.00     2020           2020-05-01    mayo  Viernes          1
# 3        821929.00     2020           2020-05-01    mayo  Viernes          1
# 4        821930.00     2020           2020-05-01    mayo  Viernes          1
# ...            ...      ...                  ...     ...      ...        ...
# 806150         nan     2020  2020-08-31 00:00:00  agosto    Lunes         31
# 806151         nan     2020  2020-08-31 00:00:00  agosto    Lunes         31
# 806152         nan     2020  2020-08-31 00:00:00  agosto    Lunes         31
# 806153         nan     2020  2020-08-31 00:00:00  agosto    Lunes         31
# 806154         nan     2020  2020-08-31 00:00:00  agosto    Lunes         31
#
#         hora_inicio  hora_fin    estacion   tipo_vehiculo forma_pago  \
# 0                 0         1     ALBERDI            Auto        Tag
# 1                 0         1     ALBERDI            Auto        Tag
# 2                 0         1  AVELLANEDA            Auto        Tag
# 3                 0         1  AVELLANEDA            Auto        Tag
# 4                 0         1  AVELLANEDA            Auto        Tag
# ...             ...       ...         ...             ...        ...
# 806150           23         0         PB1  Pesados 6 Ejes        Tag
# 806151           23         0         PB1  Pesados 6 Ejes  Violación
# 806152           23         0         PB4  Pesados 6 Ejes        Tag
# 806153           23         0         PB4  Pesados 6 Ejes        Tag
# 806154           23         0         PB4  Pesados 6 Ejes  Violación
#
#                observacion    sentido  cantidad_pasos
# 0            Tag - PosPago  Provincia               5
# 1        Tag - PosPago OCR  Provincia               2
# 2            Tag - PosPago     Centro              30
# 3            Tag - PosPago  Provincia              25
# 4        Tag - PosPago OCR     Centro               3
# ...                    ...        ...             ...
# 806150       Tag - PosPago  Provincia              17
# 806151  Violación - Normal  Provincia               2
# 806152       Tag - PosPago     Centro              24
# 806153   Tag - PosPago OCR     Centro               1
# 806154  Violación - Normal     Centro               1
#
# [806155 rows x 14 columns]

# %%
data_2020_Q3
# Out:
#         periodo      fecha         mes     dia  dia_fecha  hora_inicio  \
# 0          2020 2020-09-01  septiembre  Martes          1            0
# 1          2020 2020-09-01  septiembre  Martes          1            0
# 2          2020 2020-09-01  septiembre  Martes          1            0
# 3          2020 2020-09-01  septiembre  Martes          1            0
# 4          2020 2020-09-01  septiembre  Martes          1            0
# ...         ...        ...         ...     ...        ...          ...
# 905657     2020 2020-12-31   diciembre  Jueves         31           21
# 905658     2020 2020-12-31   diciembre  Jueves         31           21
# 905659     2020 2020-12-31   diciembre  Jueves         31           21
# 905660     2020 2020-12-31   diciembre  Jueves         31           22
# 905661     2020 2020-12-31   diciembre  Jueves         31           23
#
#         hora_fin                          estacion   tipo_vehiculo forma_pago  \
# 0              1                           ALBERDI            Auto   Efectivo
# 1              1                           ALBERDI            Auto     Exento
# 2              1                           ALBERDI            Auto     Exento
# 3              1                           ALBERDI            Auto        Tag
# 4              1                           ALBERDI            Auto        Tag
# ...          ...                               ...             ...        ...
# 905657        22  DELLEPIANE LINIERSLEPIANE CENTRO  Pesados 6 Ejes        Tag
# 905658        22                DELLEPIANE LINIERS  Pesados 6 Ejes        Tag
# 905659        22                               ILP  Pesados 6 Ejes        Tag
# 905660        23                               ILP  Pesados 6 Ejes        Tag
# 905661         0                DELLEPIANE LINIERS  Pesados 6 Ejes        Tag
#
#                    observacion    sentido  cantidad_pasos
# 0                     Efectivo  Provincia           10.00
# 1       Exento - Otros motivos  Provincia            2.00
# 2          Exento - Reglamento  Provincia            3.00
# 3                Tag - PosPago     Centro            2.00
# 4                Tag - PosPago  Provincia            8.00
# ...                        ...        ...             ...
# 905657       Tag - PosPago OCR     Centro            1.00
# 905658           Tag - PosPago  Provincia            1.00
# 905659           Tag - PosPago     Centro            1.00
# 905660           Tag - PosPago     Centro            2.00
# 905661       Tag - PosPago OCR  Provincia            1.00
#
# [905662 rows x 13 columns]

# %% [markdown]
# ## Concatenación

# %%
# Unifico datasets
data_2020_full = pd.concat([data_2020_Q1, data_2020_Q2,data_2020_Q3])

# Quito columnas que no son necesarias
data_2020_full.drop(columns = ['Unnamed: 0','periodo','mes','dia','dia_fecha','hora_inicio'], inplace = True)

data_2020_full
# Out:
#                       fecha  hora_fin                          estacion  \
# 0       2020-01-01 00:00:00         1                           ALBERDI
# 1       2020-01-01 00:00:00         1                           ALBERDI
# 2       2020-01-01 00:00:00         1                           ALBERDI
# 3       2020-01-01 00:00:00         1                           ALBERDI
# 4       2020-01-01 00:00:00         1                           ALBERDI
# ...                     ...       ...                               ...
# 905657  2020-12-31 00:00:00        22  DELLEPIANE LINIERSLEPIANE CENTRO
# 905658  2020-12-31 00:00:00        22                DELLEPIANE LINIERS
# 905659  2020-12-31 00:00:00        22                               ILP
# 905660  2020-12-31 00:00:00        23                               ILP
# 905661  2020-12-31 00:00:00         0                DELLEPIANE LINIERS
#
#          tipo_vehiculo forma_pago                       observacion  \
# 0                 Auto   Efectivo                          Efectivo
# 1                 Auto   Efectivo                          Efectivo
# 2                 Auto  Rec.Deuda                Paso en Infracción
# 3                 Auto  Rec.Deuda  Paso en infracción con Multa LPR
# 4                 Auto  Rec.Deuda  Paso en infracción con Multa LPR
# ...                ...        ...                               ...
# 905657  Pesados 6 Ejes        Tag                 Tag - PosPago OCR
# 905658  Pesados 6 Ejes        Tag                     Tag - PosPago
# 905659  Pesados 6 Ejes        Tag                     Tag - PosPago
# 905660  Pesados 6 Ejes        Tag                     Tag - PosPago
# 905661  Pesados 6 Ejes        Tag                 Tag - PosPago OCR
#
#           sentido  cantidad_pasos
# 0          Centro           24.00
# 1       Provincia           80.00
# 2       Provincia            1.00
# 3          Centro            1.00
# 4       Provincia            1.00
# ...           ...             ...
# 905657     Centro            1.00
# 905658  Provincia            1.00
# 905659     Centro            1.00
# 905660     Centro            2.00
# 905661  Provincia            1.00
#
# [2533743 rows x 8 columns]

# %% [markdown]
# ## Exploro campo observaciones

# %% [markdown]
# Mi hipótesis es es que el campo observaciones está intimamente ligado con la modalidad de pago. Es por ello que decido explorar los diferentes textos que existen, agrupados por modalidad de pago.

# %%
print('Forma de Pago en 2020','\n')
print(data_2020_full['forma_pago'].unique())
# Out:
# Forma de Pago en 2020
#
# ['Efectivo' 'Rec.Deuda' 'Tarjeta Magnética' 'Tag' 'Exento' 'Violación'
#  'CPP' 'Mercado Pago']

# %% [markdown]
# ### Modalidad Efectivo

# %%
d_efectivo = data_2020_full[data_2020_full['forma_pago'] == 'Efectivo']
d_efectivo
# Out:
#                       fecha  hora_fin                          estacion  \
# 0       2020-01-01 00:00:00         1                           ALBERDI
# 1       2020-01-01 00:00:00         1                           ALBERDI
# 11      2020-01-01 00:00:00         1                        AVELLANEDA
# 12      2020-01-01 00:00:00         1                        AVELLANEDA
# 31      2020-01-01 00:00:00         1  DELLEPIANE LINIERSLEPIANE CENTRO
# ...                     ...       ...                               ...
# 905321  2020-12-30 00:00:00         7                DELLEPIANE LINIERS
# 905383  2020-12-30 00:00:00        12                DELLEPIANE LINIERS
# 905399  2020-12-30 00:00:00        13                DELLEPIANE LINIERS
# 905416  2020-12-30 00:00:00        14                             ILLIA
# 905599  2020-12-31 00:00:00        13  DELLEPIANE LINIERSLEPIANE CENTRO
#
#          tipo_vehiculo forma_pago observacion    sentido  cantidad_pasos
# 0                 Auto   Efectivo    Efectivo     Centro           24.00
# 1                 Auto   Efectivo    Efectivo  Provincia           80.00
# 11                Auto   Efectivo    Efectivo     Centro          542.00
# 12                Auto   Efectivo    Efectivo  Provincia          596.00
# 31                Auto   Efectivo    Efectivo     Centro          369.00
# ...                ...        ...         ...        ...             ...
# 905321  Pesados 6 Ejes   Efectivo    Efectivo  Provincia            1.00
# 905383  Pesados 6 Ejes   Efectivo    Efectivo  Provincia            1.00
# 905399  Pesados 6 Ejes   Efectivo    Efectivo  Provincia            1.00
# 905416  Pesados 6 Ejes   Efectivo    Efectivo  Provincia            4.00
# 905599  Pesados 6 Ejes   Efectivo    Efectivo     Centro            1.00
#
# [264083 rows x 8 columns]

# %%
d_efectivo['observacion'].unique()
# Out:
# array(['Efectivo'], dtype=object)

# %% [markdown]
# Como se puede observar, para la modalidad de pago efectivo no aporta mayor información el campo observaciones.

# %% [markdown]
# ### Modalidad Rec. Deuda

# %%
d_rec_deuda = data_2020_full[data_2020_full['forma_pago'] == 'Rec.Deuda']
d_rec_deuda
# Out:
#                       fecha  hora_fin                          estacion  \
# 2       2020-01-01 00:00:00         1                           ALBERDI
# 3       2020-01-01 00:00:00         1                           ALBERDI
# 4       2020-01-01 00:00:00         1                           ALBERDI
# 15      2020-01-01 00:00:00         1                        AVELLANEDA
# 16      2020-01-01 00:00:00         1                        AVELLANEDA
# ...                     ...       ...                               ...
# 904901  2020-12-28 00:00:00        17                DELLEPIANE LINIERS
# 905177  2020-12-29 00:00:00        17                DELLEPIANE LINIERS
# 905195  2020-12-29 00:00:00        18                DELLEPIANE LINIERS
# 905334  2020-12-30 00:00:00         8                DELLEPIANE LINIERS
# 905396  2020-12-30 00:00:00        13  DELLEPIANE LINIERSLEPIANE CENTRO
#
#          tipo_vehiculo forma_pago                       observacion  \
# 2                 Auto  Rec.Deuda                Paso en Infracción
# 3                 Auto  Rec.Deuda  Paso en infracción con Multa LPR
# 4                 Auto  Rec.Deuda  Paso en infracción con Multa LPR
# 15                Auto  Rec.Deuda                Paso en Infracción
# 16                Auto  Rec.Deuda                Paso en Infracción
# ...                ...        ...                               ...
# 904901  Pesados 6 Ejes  Rec.Deuda  Paso en infracción con Multa LPR
# 905177  Pesados 6 Ejes  Rec.Deuda  Paso en infracción con Multa LPR
# 905195  Pesados 6 Ejes  Rec.Deuda                Paso en Infracción
# 905334  Pesados 6 Ejes  Rec.Deuda  Paso en infracción con Multa LPR
# 905396  Pesados 6 Ejes  Rec.Deuda                Paso en Infracción
#
#           sentido  cantidad_pasos
# 2       Provincia            1.00
# 3          Centro            1.00
# 4       Provincia            1.00
# 15         Centro            7.00
# 16      Provincia            9.00
# ...           ...             ...
# 904901  Provincia            1.00
# 905177  Provincia            1.00
# 905195  Provincia            1.00
# 905334  Provincia            1.00
# 905396     Centro            1.00
#
# [187388 rows x 8 columns]

# %%
d_rec_deuda['observacion'].unique()
# Out:
# array(['Paso en Infracción', 'Paso en infracción con Multa LPR',
#        'Paso a facturar - (colectivo)', 'Paso en Infracción con Multa'],
#       dtype=object)

# %% [markdown]
# Es interesante observar que bajo esta modalidad, se los identifica con infración y con una deuda a cobrar. No se explicita si es cobrada en el momento o queda informada para ser cobrada en el futuro.

# %% [markdown]
# ### Modalidad Tarjeta Magnética

# %%
d_t_mag = data_2020_full[data_2020_full['forma_pago'] == 'Tarjeta Magnética']
d_t_mag
# Out:
#                       fecha  hora_fin                          estacion  \
# 5       2020-01-01 00:00:00         1                           ALBERDI
# 19      2020-01-01 00:00:00         1                        AVELLANEDA
# 20      2020-01-01 00:00:00         1                        AVELLANEDA
# 36      2020-01-01 00:00:00         1  DELLEPIANE LINIERSLEPIANE CENTRO
# 47      2020-01-01 00:00:00         1                DELLEPIANE LINIERS
# ...                     ...       ...                               ...
# 868748  2020-12-30 00:00:00        17  DELLEPIANE LINIERSLEPIANE CENTRO
# 868801  2020-12-30 00:00:00        18                DELLEPIANE LINIERS
# 868895  2020-12-30 00:00:00        20                             ILLIA
# 869402  2020-12-31 00:00:00        15  DELLEPIANE LINIERSLEPIANE CENTRO
# 886112  2020-12-30 00:00:00         7  DELLEPIANE LINIERSLEPIANE CENTRO
#
#          tipo_vehiculo         forma_pago        observacion    sentido  \
# 5                 Auto  Tarjeta Magnética  T.Magnética Disc.     Centro
# 19                Auto  Tarjeta Magnética  T.Magnética Disc.     Centro
# 20                Auto  Tarjeta Magnética  T.Magnética Disc.  Provincia
# 36                Auto  Tarjeta Magnética  T.Magnética Disc.     Centro
# 47                Auto  Tarjeta Magnética  T.Magnética Disc.  Provincia
# ...                ...                ...                ...        ...
# 868748  Pesados 2 Ejes  Tarjeta Magnética  T.Magnética Disc.     Centro
# 868801  Pesados 2 Ejes  Tarjeta Magnética  T.Magnética Disc.  Provincia
# 868895  Pesados 2 Ejes  Tarjeta Magnética  T.Magnética Disc.     Centro
# 869402  Pesados 2 Ejes  Tarjeta Magnética  T.Magnética Disc.     Centro
# 886112  Pesados 4 Ejes  Tarjeta Magnética  T.Magnética Disc.     Centro
#
#         cantidad_pasos
# 5                 4.00
# 19               12.00
# 20               10.00
# 36                5.00
# 47                8.00
# ...                ...
# 868748            1.00
# 868801            1.00
# 868895            1.00
# 869402            1.00
# 886112            1.00
#
# [50495 rows x 8 columns]

# %%
d_t_mag['observacion'].unique()
# Out:
# array(['T.Magnética Disc.'], dtype=object)

# %% [markdown]
# Gracias a esta exploración, se puede saber que es la nueva modalidad de identificar a la modalidad que años anteriores nombraban como *TARJETA DISCAPACIDAD*.

# %% [markdown]
# ### Modalidad Tag

# %%
d_tag = data_2020_full[data_2020_full['forma_pago'] == 'Tag']
d_tag
# Out:
#                       fecha  hora_fin                          estacion  \
# 6       2020-01-01 00:00:00         1                           ALBERDI
# 7       2020-01-01 00:00:00         1                           ALBERDI
# 8       2020-01-01 00:00:00         1                           ALBERDI
# 9       2020-01-01 00:00:00         1                           ALBERDI
# 10      2020-01-01 00:00:00         1                           ALBERDI
# ...                     ...       ...                               ...
# 905657  2020-12-31 00:00:00        22  DELLEPIANE LINIERSLEPIANE CENTRO
# 905658  2020-12-31 00:00:00        22                DELLEPIANE LINIERS
# 905659  2020-12-31 00:00:00        22                               ILP
# 905660  2020-12-31 00:00:00        23                               ILP
# 905661  2020-12-31 00:00:00         0                DELLEPIANE LINIERS
#
#          tipo_vehiculo forma_pago        observacion    sentido  \
# 6                 Auto        Tag      Tag - PosPago     Centro
# 7                 Auto        Tag      Tag - PosPago  Provincia
# 8                 Auto        Tag  Tag - PosPago OCR     Centro
# 9                 Auto        Tag  Tag - PosPago OCR  Provincia
# 10                Auto        Tag      Tag - PrePago     Centro
# ...                ...        ...                ...        ...
# 905657  Pesados 6 Ejes        Tag  Tag - PosPago OCR     Centro
# 905658  Pesados 6 Ejes        Tag      Tag - PosPago  Provincia
# 905659  Pesados 6 Ejes        Tag      Tag - PosPago     Centro
# 905660  Pesados 6 Ejes        Tag      Tag - PosPago     Centro
# 905661  Pesados 6 Ejes        Tag  Tag - PosPago OCR  Provincia
#
#         cantidad_pasos
# 6                 9.00
# 7                56.00
# 8                 4.00
# 9                14.00
# 10                1.00
# ...                ...
# 905657            1.00
# 905658            1.00
# 905659            1.00
# 905660            2.00
# 905661            1.00
#
# [1429726 rows x 8 columns]

# %%
d_tag['observacion'].unique()
# Out:
# array(['Tag - PosPago', 'Tag - PosPago OCR', 'Tag - PrePago',
#        'Tag - PrePago OCR', 'Metrobus no hab. TAG pospago',
#        'Metrobus no hab. OCR pospago', 'Metrobus no hab. TAG prepago',
#        'Metrobus no hab. OCR prepago', 'Tag - Exento'], dtype=object)

# %% [markdown]
# Según lo investigado en la página oficial de Ausa [link](https://www.ausa.com.ar/novedades/ahora-podes-tener-tu-telepase-sin-tarjeta-de-credito/) se puede apreciar como *Telepase* pasa a ser *Tag* y lo lista como inminentemente el único médio de pago válido.
#
# Las diferencias que encontramos entre *PosPago* y *PrePago* son las modalidades que ofrece el sistema. Por otro lado, se puede observar que con la tecnología del *Telepase*, ya identifican a los *Exento*.
#
# Finalmente, nos encontramos con las observaciones sobre *Metrobus*, en donde están por un lado se encuentran las modalidades de pre y pospago, y por el otro, dos tipos de tecnología: TAG u OCR (es posible que esta última haga referencia a la que se utiliza para el reconocimeinto de patentes - [Link](https://es.wikipedia.org/wiki/Reconocimiento_autom%C3%A1tico_de_matr%C3%ADculas)).

# %% [markdown]
# ### Modalidad Exento

# %%
d_exento = data_2020_full[data_2020_full['forma_pago'] == 'Exento']
d_exento
# Out:
#                       fecha  hora_fin                          estacion  \
# 13      2020-01-01 00:00:00         1                        AVELLANEDA
# 14      2020-01-01 00:00:00         1                        AVELLANEDA
# 32      2020-01-01 00:00:00         1  DELLEPIANE LINIERSLEPIANE CENTRO
# 33      2020-01-01 00:00:00         1  DELLEPIANE LINIERSLEPIANE CENTRO
# 43      2020-01-01 00:00:00         1                DELLEPIANE LINIERS
# ...                     ...       ...                               ...
# 895042  2020-12-21 00:00:00         0                             ILLIA
# 897339  2020-12-29 00:00:00         8  DELLEPIANE LINIERSLEPIANE CENTRO
# 897953  2020-12-30 00:00:00        17                DELLEPIANE LINIERS
# 902127  2020-12-16 00:00:00        14  DELLEPIANE LINIERSLEPIANE CENTRO
# 905267  2020-12-29 00:00:00         0                DELLEPIANE LINIERS
#
#          tipo_vehiculo forma_pago             observacion    sentido  \
# 13                Auto     Exento     Exento - Reglamento     Centro
# 14                Auto     Exento     Exento - Reglamento  Provincia
# 32                Auto     Exento  Exento - Otros motivos     Centro
# 33                Auto     Exento     Exento - Reglamento     Centro
# 43                Auto     Exento  Exento - Otros motivos  Provincia
# ...                ...        ...                     ...        ...
# 895042  Pesados 5 Ejes     Exento  Exento - Otros motivos     Centro
# 897339  Pesados 5 Ejes     Exento     Exento - Reglamento     Centro
# 897953  Pesados 5 Ejes     Exento     Exento - Reglamento  Provincia
# 902127  Pesados 6 Ejes     Exento     Exento - Reglamento     Centro
# 905267  Pesados 6 Ejes     Exento     Exento - Reglamento  Provincia
#
#         cantidad_pasos
# 13                7.00
# 14                4.00
# 32                4.00
# 33                3.00
# 43                1.00
# ...                ...
# 895042            1.00
# 897339            1.00
# 897953            1.00
# 902127            1.00
# 905267            1.00
#
# [149718 rows x 8 columns]

# %%
d_exento['observacion'].unique()
# Out:
# array(['Exento - Reglamento', 'Exento - Otros motivos',
#        'Exento - Demora en cobro'], dtype=object)

# %% [markdown]
# Se puede apreciar que expone subtipos de modalidad *Exento*. Probablemente sea útil a la hora de trabajar con este subgrupo.

# %% [markdown]
# ### Modalidad Violación

# %%
d_violacion = data_2020_full[data_2020_full['forma_pago'] == 'Violación']
d_violacion
# Out:
#                       fecha  hora_fin                          estacion  \
# 29      2020-01-01 00:00:00         1                        AVELLANEDA
# 30      2020-01-01 00:00:00         1                        AVELLANEDA
# 41      2020-01-01 00:00:00         1  DELLEPIANE LINIERSLEPIANE CENTRO
# 70      2020-01-01 00:00:00         1                             ILLIA
# 73      2020-01-01 00:00:00         1                               ILP
# ...                     ...       ...                               ...
# 905616  2020-12-31 00:00:00        14                               ILP
# 905625  2020-12-31 00:00:00        15                               ILP
# 905639  2020-12-31 00:00:00        17                               ILP
# 905644  2020-12-31 00:00:00        18                               ILP
# 905649  2020-12-31 00:00:00        19                               ILP
#
#          tipo_vehiculo forma_pago         observacion    sentido  \
# 29                Auto  Violación  Violación - Normal     Centro
# 30                Auto  Violación  Violación - Normal  Provincia
# 41                Auto  Violación  Violación - Normal     Centro
# 70                Auto  Violación  Violación - Normal  Provincia
# 73                Auto  Violación  Violación - Normal     Centro
# ...                ...        ...                 ...        ...
# 905616  Pesados 6 Ejes  Violación  Violación - Normal     Centro
# 905625  Pesados 6 Ejes  Violación  Violación - Normal     Centro
# 905639  Pesados 6 Ejes  Violación  Violación - Normal  Provincia
# 905644  Pesados 6 Ejes  Violación  Violación - Normal     Centro
# 905649  Pesados 6 Ejes  Violación  Violación - Normal     Centro
#
#         cantidad_pasos
# 29                3.00
# 30                2.00
# 41                1.00
# 70                1.00
# 73                2.00
# ...                ...
# 905616            1.00
# 905625            2.00
# 905639            1.00
# 905644            1.00
# 905649            1.00
#
# [424291 rows x 8 columns]

# %%
d_violacion['observacion'].unique()
# Out:
# array(['Violación - Normal', 'Violación - Via Liberada',
#        'Violación - Rebote', 'Violación - Repetitiva',
#        'Violación - Vía Cerrada'], dtype=object)

# %% [markdown]
# Se observa diferentes subgrupos para esta modalidad.

# %% [markdown]
# ### Modalidad CPP

# %%
d_cpp = data_2020_full[data_2020_full['forma_pago'] == 'CPP']
d_cpp
# Out:
#                       fecha  hora_fin    estacion   tipo_vehiculo forma_pago  \
# 619205  2020-03-18 00:00:00        11  AVELLANEDA            Auto        CPP
# 619321  2020-03-18 00:00:00        12  AVELLANEDA            Auto        CPP
# 619445  2020-03-18 00:00:00        13  AVELLANEDA            Auto        CPP
# 621520  2020-03-18 00:00:00        11  AVELLANEDA             N/D        CPP
# 621547  2020-03-18 00:00:00        12  AVELLANEDA             N/D        CPP
# ...                     ...       ...         ...             ...        ...
# 155552           2020-05-01        10  AVELLANEDA  Pesados 6 Ejes        CPP
# 155583           2020-05-01        13  AVELLANEDA  Pesados 6 Ejes        CPP
# 155595           2020-05-01        14  AVELLANEDA  Pesados 6 Ejes        CPP
# 155596           2020-05-01        14  AVELLANEDA  Pesados 6 Ejes        CPP
# 155836           2020-05-02        11       ILLIA  Pesados 6 Ejes        CPP
#
#        observacion    sentido  cantidad_pasos
# 619205     Obs CPP     Centro            3.00
# 619321     Obs CPP     Centro           28.00
# 619445     Obs CPP     Centro           30.00
# 621520     Obs CPP     Centro            4.00
# 621547     Obs CPP     Centro            2.00
# ...            ...        ...             ...
# 155552     Obs CPP     Centro            2.00
# 155583     Obs CPP  Provincia            2.00
# 155595     Obs CPP     Centro            1.00
# 155596     Obs CPP  Provincia            1.00
# 155836     Obs CPP  Provincia            1.00
#
# [17379 rows x 8 columns]

# %%
d_cpp['observacion'].unique()
# Out:
# array(['Obs CPP'], dtype=object)

# %% [markdown]
# El campo observaciones no aporta mayor información para este caso, dado que en todos el texto es el mismo "Obs CPP".

# %% [markdown]
# ### Modalidad Mercado Pago

# %%
d_mp = data_2020_full[data_2020_full['forma_pago'] == 'Mercado Pago']
d_mp
# Out:
#                       fecha  hora_fin                          estacion  \
# 674478  2020-12-21 00:00:00         9                               PB1
# 674519  2020-12-21 00:00:00        12                               PB1
# 674531  2020-12-21 00:00:00        12                               PB4
# 674535  2020-12-21 00:00:00        13                               PB1
# 674596  2020-12-21 00:00:00        17                               PB2
# ...                     ...       ...                               ...
# 897540  2020-12-29 00:00:00        17                               ILP
# 897552  2020-12-29 00:00:00        18  DELLEPIANE LINIERSLEPIANE CENTRO
# 897597  2020-12-29 00:00:00        20  DELLEPIANE LINIERSLEPIANE CENTRO
# 897924  2020-12-30 00:00:00        16  DELLEPIANE LINIERSLEPIANE CENTRO
# 897925  2020-12-30 00:00:00        16  DELLEPIANE LINIERSLEPIANE CENTRO
#
#          tipo_vehiculo    forma_pago       observacion    sentido  \
# 674478            Auto  Mercado Pago      Mercado Pago  Provincia
# 674519            Auto  Mercado Pago      Mercado Pago  Provincia
# 674531            Auto  Mercado Pago      Mercado Pago     Centro
# 674535            Auto  Mercado Pago      Mercado Pago  Provincia
# 674596            Auto  Mercado Pago  Mercado Pago OCR     Centro
# ...                ...           ...               ...        ...
# 897540  Pesados 5 Ejes  Mercado Pago      Mercado Pago     Centro
# 897552  Pesados 5 Ejes  Mercado Pago      Mercado Pago     Centro
# 897597  Pesados 5 Ejes  Mercado Pago      Mercado Pago     Centro
# 897924  Pesados 5 Ejes  Mercado Pago      Mercado Pago     Centro
# 897925  Pesados 5 Ejes  Mercado Pago  Mercado Pago OCR     Centro
#
#         cantidad_pasos
# 674478            1.00
# 674519            1.00
# 674531            1.00
# 674535            1.00
# 674596            1.00
# ...                ...
# 897540            1.00
# 897552            1.00
# 897597            1.00
# 897924            1.00
# 897925            1.00
#
# [10663 rows x 8 columns]

# %%
d_mp['observacion'].unique()
# Out:
# array(['Mercado Pago', 'Mercado Pago OCR',
#        'Metrobus no hab. TAG Mercado Pago'], dtype=object)

# %% [markdown]
# Se aprecian diferentes subgrupos bajo la modalidad *mercado Pago*.

# %% [markdown]
# ### Conclusión
#
# Se puede validar la hipótesis donde el campo observaciones está intimamente ligado a la modalidad de pago.
# En ocaciones, denota que se pueden obtener subgrupos o mayor información. En otros casos como en el de *Efectivo*, no aporta más datos.
#
# Fue importante poder explorarlo para poder detectar por ej, que la modalidad *Tarjeta Magnética* es la nueva nomenclatura para *Tarjeta Discapacidad*.

# %% [markdown]
# ## Unifico criterios

# %% [markdown]
# Para que tengan una coherencia con los años anteriores, unifico criterios en los términos utilizados.

# %%
# Modifico Naming de forma de pago
data_2020_full['forma_pago'] = data_2020_full['forma_pago'].replace({
    'Efectivo':'EFECTIVO',
    'Tarjeta Magnética':'TARJETA DISCAPACIDAD',
    'Tag':'TELEPASE',
})

# %%
# Verifico modalidades de pago
data_2020_full['forma_pago'].unique()
# Out:
# array(['EFECTIVO', 'Rec.Deuda', 'TARJETA DISCAPACIDAD', 'TELEPASE',
#        'Exento', 'Violación', 'CPP', 'Mercado Pago'], dtype=object)

# %%
print('Estaciones en 2020','\n')
print(data_2020_full['estacion'].unique())
# Out:
# Estaciones en 2020
#
# ['ALBERDI' 'AVELLANEDA' 'DELLEPIANE LINIERSLEPIANE CENTRO'
#  'DELLEPIANE LINIERS' 'ILLIA' 'ILP' 'PB1' 'PB3' 'PB4' 'RETIRO' 'SALGUERO'
#  'SARMIENTO' 'PB2']

# %%
# Unifico estaciones
data_2020_full['estacion'] = data_2020_full['estacion'].str.title()
data_2020_full['estacion'] = data_2020_full['estacion'].replace({
    'Ilp':'Illia',
    'Pb1':'PDB',
    'Pb2':'PDB',
    'Pb3':'PDB',
    'Pb4':'PDB',
    'Dellepiane Linierslepiane Centro':'Dellepiane',
    'Dellepiane Liniers':'Dellepiane',
})

# %%
# Verifico estaciones
data_2020_full['estacion'].unique()
# Out:
# array(['Alberdi', 'Avellaneda', 'Dellepiane', 'Illia', 'PDB', 'Retiro',
#        'Salguero', 'Sarmiento'], dtype=object)

# %% [markdown]
# ## Disminución del dataset

# %% [markdown]
# Con el objetivo de disminuir el tamaño del dataset, y ya habiendo explorado el campo *observaciones*, procedo a eliminarlo.

# %%
data_2020 = data_2020_full.copy()

# %%
# Quito el campo observaciones
data_2020.drop(columns = ['observacion'], inplace = True)

# %% [markdown]
# Para evitar el error de github "*this exceeds GitHub's file size limit of 100.00 MB*", realizaré dos datasets

# %%
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
data_2020['fecha2'] = pd.to_datetime(data_2020.fecha) + pd.to_timedelta(data_2020.hora_fin, unit = 'h')

#Quitamos las columnas que ya no vamos a utilizar
data_2020.drop(columns=['hora_fin', 'fecha'], inplace = True)

#Corregimos el nombre de fecha2 a fecha
data_2020.rename(columns = {'fecha2':'fecha'}, inplace = True) 

#Reordenamos el dataset por fecha
data_2020.sort_values('fecha', inplace = True)
data_2020.reset_index(drop=True, inplace = True)

data_2020
# Out:
#            estacion   tipo_vehiculo    forma_pago    sentido  cantidad_pasos  \
# 0               PDB  Pesados 4 Ejes      TELEPASE  Provincia            3.00
# 1        Dellepiane            Auto        Exento  Provincia            6.00
# 2        Dellepiane            Auto      EFECTIVO  Provincia          443.00
# 3        Dellepiane            Auto      TELEPASE     Centro            2.00
# 4        Dellepiane            Auto      TELEPASE     Centro            7.00
# ...             ...             ...           ...        ...             ...
# 2533738     Alberdi            Auto      TELEPASE     Centro           18.00
# 2533739     Alberdi            Auto  Mercado Pago     Centro            2.00
# 2533740     Alberdi            Auto  Mercado Pago  Provincia            1.00
# 2533741  Avellaneda            Auto      TELEPASE  Provincia            5.95
# 2533742  Dellepiane            Auto  Mercado Pago  Provincia            6.00
#
#                       fecha
# 0       2020-01-01 00:00:00
# 1       2020-01-01 00:00:00
# 2       2020-01-01 00:00:00
# 3       2020-01-01 00:00:00
# 4       2020-01-01 00:00:00
# ...                     ...
# 2533738 2020-12-31 23:00:00
# 2533739 2020-12-31 23:00:00
# 2533740 2020-12-31 23:00:00
# 2533741 2020-12-31 23:00:00
# 2533742 2020-12-31 23:00:00
#
# [2533743 rows x 6 columns]

# %%
data_2020_s1 = data_2020[
                     (data_2020['fecha'] <= '2020-06-30 23:00:00')
                    ]
data_2020_s1
# Out:
#            estacion   tipo_vehiculo forma_pago    sentido  cantidad_pasos  \
# 0               PDB  Pesados 4 Ejes   TELEPASE  Provincia            3.00
# 1        Dellepiane            Auto     Exento  Provincia            6.00
# 2        Dellepiane            Auto   EFECTIVO  Provincia          443.00
# 3        Dellepiane            Auto   TELEPASE     Centro            2.00
# 4        Dellepiane            Auto   TELEPASE     Centro            7.00
# ...             ...             ...        ...        ...             ...
# 1205363  Avellaneda  Pesados 4 Ejes   EFECTIVO  Provincia            1.00
# 1205364   Sarmiento             N/D  Violación  Provincia            8.00
# 1205365       Illia  Pesados 4 Ejes  Violación     Centro            1.00
# 1205366  Avellaneda  Pesados 4 Ejes   EFECTIVO     Centro            2.00
# 1205367  Dellepiane  Pesados 4 Ejes   TELEPASE  Provincia            2.00
#
#                       fecha
# 0       2020-01-01 00:00:00
# 1       2020-01-01 00:00:00
# 2       2020-01-01 00:00:00
# 3       2020-01-01 00:00:00
# 4       2020-01-01 00:00:00
# ...                     ...
# 1205363 2020-06-30 23:00:00
# 1205364 2020-06-30 23:00:00
# 1205365 2020-06-30 23:00:00
# 1205366 2020-06-30 23:00:00
# 1205367 2020-06-30 23:00:00
#
# [1205368 rows x 6 columns]

# %%
data_2020_s2 = data_2020[
                     (data_2020['fecha'] > '2020-06-30 23:00:00')
                    ]
data_2020_s2
# Out:
#            estacion tipo_vehiculo    forma_pago    sentido  cantidad_pasos  \
# 1205368  Avellaneda          Moto     Rec.Deuda  Provincia            1.00
# 1205369  Avellaneda          Moto      EFECTIVO  Provincia           14.00
# 1205370  Dellepiane           N/D     Violación     Centro            1.00
# 1205371  Avellaneda          Moto      TELEPASE     Centro            1.00
# 1205372     Alberdi          Moto      EFECTIVO  Provincia            1.00
# ...             ...           ...           ...        ...             ...
# 2533738     Alberdi          Auto      TELEPASE     Centro           18.00
# 2533739     Alberdi          Auto  Mercado Pago     Centro            2.00
# 2533740     Alberdi          Auto  Mercado Pago  Provincia            1.00
# 2533741  Avellaneda          Auto      TELEPASE  Provincia            5.95
# 2533742  Dellepiane          Auto  Mercado Pago  Provincia            6.00
#
#                       fecha
# 1205368 2020-07-01 00:00:00
# 1205369 2020-07-01 00:00:00
# 1205370 2020-07-01 00:00:00
# 1205371 2020-07-01 00:00:00
# 1205372 2020-07-01 00:00:00
# ...                     ...
# 2533738 2020-12-31 23:00:00
# 2533739 2020-12-31 23:00:00
# 2533740 2020-12-31 23:00:00
# 2533741 2020-12-31 23:00:00
# 2533742 2020-12-31 23:00:00
#
# [1328375 rows x 6 columns]

# %% [markdown]
# Valido que tenga todos los rows:

# %%
if (data_2020.shape[0] == (data_2020_s1.shape[0] + data_2020_s2.shape[0])):
    print('Es correcto')
else:
    print('Revisar separación de semestres')
# Out:
# Es correcto

# %% [markdown]
# ## Exporto CSV

# %%
# Exporto 
data_2020_s1.to_csv('datasets/flujo-vehicular-2020-S1.csv', index = False)
data_2020_s2.to_csv('datasets/flujo-vehicular-2020-S2.csv', index = False)

# %%
# Verifico exportación

check_1 = pd.read_csv('./datasets/flujo-vehicular-2020-S1.csv')
check_1
# Out:
#            estacion   tipo_vehiculo forma_pago    sentido  cantidad_pasos  \
# 0               PDB  Pesados 4 Ejes   TELEPASE  Provincia            3.00
# 1        Dellepiane            Auto     Exento  Provincia            6.00
# 2        Dellepiane            Auto   EFECTIVO  Provincia          443.00
# 3        Dellepiane            Auto   TELEPASE     Centro            2.00
# 4        Dellepiane            Auto   TELEPASE     Centro            7.00
# ...             ...             ...        ...        ...             ...
# 1205363  Avellaneda  Pesados 4 Ejes   EFECTIVO  Provincia            1.00
# 1205364   Sarmiento             N/D  Violación  Provincia            8.00
# 1205365       Illia  Pesados 4 Ejes  Violación     Centro            1.00
# 1205366  Avellaneda  Pesados 4 Ejes   EFECTIVO     Centro            2.00
# 1205367  Dellepiane  Pesados 4 Ejes   TELEPASE  Provincia            2.00
#
#                        fecha
# 0        2020-01-01 00:00:00
# 1        2020-01-01 00:00:00
# 2        2020-01-01 00:00:00
# 3        2020-01-01 00:00:00
# 4        2020-01-01 00:00:00
# ...                      ...
# 1205363  2020-06-30 23:00:00
# 1205364  2020-06-30 23:00:00
# 1205365  2020-06-30 23:00:00
# 1205366  2020-06-30 23:00:00
# 1205367  2020-06-30 23:00:00
#
# [1205368 rows x 6 columns]

# %%
check_2 = pd.read_csv('./datasets/flujo-vehicular-2020-S2.csv')
check_2
# Out:
#            estacion tipo_vehiculo    forma_pago    sentido  cantidad_pasos  \
# 0        Avellaneda          Moto     Rec.Deuda  Provincia            1.00
# 1        Avellaneda          Moto      EFECTIVO  Provincia           14.00
# 2        Dellepiane           N/D     Violación     Centro            1.00
# 3        Avellaneda          Moto      TELEPASE     Centro            1.00
# 4           Alberdi          Moto      EFECTIVO  Provincia            1.00
# ...             ...           ...           ...        ...             ...
# 1328370     Alberdi          Auto      TELEPASE     Centro           18.00
# 1328371     Alberdi          Auto  Mercado Pago     Centro            2.00
# 1328372     Alberdi          Auto  Mercado Pago  Provincia            1.00
# 1328373  Avellaneda          Auto      TELEPASE  Provincia            5.95
# 1328374  Dellepiane          Auto  Mercado Pago  Provincia            6.00
#
#                        fecha
# 0        2020-07-01 00:00:00
# 1        2020-07-01 00:00:00
# 2        2020-07-01 00:00:00
# 3        2020-07-01 00:00:00
# 4        2020-07-01 00:00:00
# ...                      ...
# 1328370  2020-12-31 23:00:00
# 1328371  2020-12-31 23:00:00
# 1328372  2020-12-31 23:00:00
# 1328373  2020-12-31 23:00:00
# 1328374  2020-12-31 23:00:00
#
# [1328375 rows x 6 columns]
